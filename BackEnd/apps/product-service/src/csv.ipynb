# %%
import csv
import json

with open('data.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    writer.writerow([
        'name',
        'category',
        'brand',
        'description',
        'price',
        'stock',
        'attributes',
    ])
    
    writer.writerow([
        'Asus ROG Azoth X',
        'Keyboard',
        'ASUS',
        'The ASUS ROG Azoth X is a high-performance gaming keyboard designed for gamers who demand precision and speed. It features customizable RGB lighting, mechanical switches for tactile feedback, and a durable build to withstand intense gaming sessions. With its ergonomic design and programmable keys, the ROG Azoth X offers an immersive gaming experience and allows users to personalize their setup to suit their preferences',
        802,
        200,
        json.dumps({
            'Support': 'Windows 10, Windows 11',
            'Polling': '1000Hz',
            'Model': '90MP044F-BKUA30 (ROG NX Snow V2)',
            'color': 'White',
        })
    ])
    
    writer.writerow([
        'Asus ROG Azoth X',
        'Keyboard',
        'ASUS',
        'The ASUS ROG Azoth X is a high-performance gaming keyboard designed for gamers who demand precision and speed. It features customizable RGB lighting, mechanical switches for tactile feedback, and a durable build to withstand intense gaming sessions. With its ergonomic design and programmable keys, the ROG Azoth X offers an immersive gaming experience and allows users to personalize their setup to suit their preferences',
        302,
        230,
        json.dumps({
            'Support': 'Windows 10, Windows 11, Bluetooth 5.2',
            'Connect': 'Wireless, Wired',
            'SWITCH': 'DareU DREAM (Linear), DareU FIRE-FLY (Tactile)',
            'color': 'Black',
        })
    ])
    
    writer.writerow([
        'Asus ROG Azoth X',
        'Keyboard',
        'ASUS',
        'The ASUS ROG Azoth X is a high-performance gaming keyboard designed for gamers who demand precision and speed. It features customizable RGB lighting, mechanical switches for tactile feedback, and a durable build to withstand intense gaming sessions. With its ergonomic design and programmable keys, the ROG Azoth X offers an immersive gaming experience and allows users to personalize their setup to suit their preferences',
        602,
        230,
        json.dumps({
            'Support': 'Windows 10, Windows 11, Bluetooth 5.2',
            'Connect': 'USB-C, Wireless',
            'Layout': '80 key + 1 knob (US)',
            'color': 'Black, White',
            'Keycap': 'Double-shot PBT',
        })
    ])
    
    writer.writerow([
        'RAM Adata XPG Lancer Blade',
        'Storage',
        'XPG',
        'High performance RAM for gaming',
        5420,
        330,
        json.dumps({
            'Storage': '32GB (2×16GB)',
            'Color': 'White',
            'Connect': '288-Pin',
            'Delay': 'CL46',
            'Bus': '5600MHz',
        })
    ])
    
    writer.writerow([
        'RAM Adata XPG Lancer Blade',
        'Storage',
        'XPG',
        'High performance RAM for gaming',
        4420,
        380,
        json.dumps({
            'Storage': '16GB (2×8GB)',
            'Color': 'Black',
            'Connect': '288-Pin',
            'Delay': 'CL46',
            'Bus': '2800 MHz',
        })
    ])
